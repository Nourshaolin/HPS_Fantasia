# %% [markdown]
# <a href="https://colab.research.google.com/github/Nourshaolin/HPS_Fantasia/blob/main/Fantasia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Just to check")
# Out:
# Just to check
